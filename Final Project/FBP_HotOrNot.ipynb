# %%
import pandas as pd
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow import keras
from tensorflow.keras import preprocessing
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import ZeroPadding2D
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers.core import Dropout, Flatten, Activation, Dense
from tensorflow.python.keras.layers.convolutional import Convolution2D
from tensorflow.python.keras.layers.pooling import MaxPooling2D

# %%
train_df = pd.read_csv("./Eccv2010.csv", sep=",", index_col=False)
train_df['purpose'] = 'train'
np.random.seed(12) #important for reproducability
val_set_size = int((20*train_df.shape[0])/100)
val_idx = np.random.choice(train_df.shape[0], size=val_set_size)
test_set_size = int((50*val_idx.shape[0])/100)
test_idx = np.random.choice(val_idx.shape[0], size=test_set_size)
train_df.loc[val_idx, 'purpose'] = 'validation'
train_df.loc[test_idx, 'purpose'] = 'test'
 
df = train_df
 
df.sample(10)
# Out:
#       index                                    filename     score  \
# 469     469  hotornot_face/female_20_BRRYRMB_face_0.jpg  1.095278
# 659     659  hotornot_face/female_21_RRO8ERA_face_2.jpg -0.282844
# 67       67  hotornot_face/female_18_BZRLKYA_face_0.jpg  0.055059
# 1868   1868  hotornot_face/female_24_AEOYBQK_face_1.jpg  0.073496
# 1404   1404  hotornot_face/female_18_RRRUHEA_face_0.jpg  0.792001
# 1554   1554  hotornot_face/female_18_AZNUEMA_face_0.jpg  0.015437
# 1485   1485  hotornot_face/female_24_AZAQRSE_face_2.jpg -1.275796
# 324     324  hotornot_face/female_19_AZA8OLK_face_1.jpg  1.375965
# 1242   1242  hotornot_face/female_33_RLOSSZR_face_1.jpg -0.745809
# 911     911  hotornot_face/female_24_RRHSGQB_face_0.jpg -2.182065
#
#       num_ratings     purpose
# 469             6       train
# 659             6       train
# 67              9        test
# 1868            4       train
# 1404            5       train
# 1554            8  validation
# 1485            5       train
# 324             8        test
# 1242            7       train
# 911             7  validation

# %%
def retrievePixels(img_name):
    path = "./eccv2010_beauty_data/%s" % (img_name)
    img = preprocessing.image.load_img(path, grayscale=False, target_size=(128, 128))
    x = preprocessing.image.img_to_array(img).reshape(1, -1)[0]
    return x
 
df['pixels'] = df['filename'].apply(retrievePixels)

features = []
pixels = df['pixels'].values
for i in range(0, pixels.shape[0]):
    features.append(pixels[i])
 
features = np.array(features)
features = features.reshape(features.shape[0], 128, 128, 3)
features = features / 255 #normalize inputs within [0, 1]

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(128,128, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(Convolution2D(4096, (4, 4), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# from keras.models import model_from_json
#load pre-trained weights of vgg-face model.
#you can find it here: https://drive.google.com/file/d/1CPSeum3HpopfomUEK1gybeuIVoeJT_Eo/view?usp=sharing
#related blog post: https://sefiks.com/2018/08/06/deep-face-recognition-with-keras/
# model.load_weights('./vgg_face_weights.h5')

# %%
num_of_classes = 1 #this is a regression problem
 
#freeze all layers of VGG-Face except last 7 one
for layer in model.layers[:-7]:
    layer.trainable = False
 
base_model_output = Sequential()
base_model_output = Flatten()(model.layers[-4].output)
base_model_output = Dense(num_of_classes)(base_model_output)
 
beauty_model = Model(inputs=model.input, outputs=base_model_output)

beauty_model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam())
 
checkpointer = ModelCheckpoint(
    filepath='eccv_beauty_model.hdf5'
    , monitor = "val_loss"
    , verbose=1
    , save_best_only=True
    , mode = 'auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=50)

# %%
train_idx = df[(df['purpose'] == 'train')].index
val_idx = df[(df['purpose'] == 'validation')].index
test_idx = df[(df['purpose'] == 'test')].index

# %%
score = beauty_model.fit(
    features[train_idx], df.iloc[train_idx].score
    , epochs=200
    , validation_data=(features[val_idx], df.iloc[val_idx].score)
    , callbacks=[checkpointer, earlyStop]
)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 52s 826ms/step - loss: 1.5541 - val_loss: 1.4796
#
# Epoch 00001: val_loss improved from inf to 1.47960, saving model to eccv_beauty_model.hdf5
# Epoch 2/200
# 49/49 [==============================] - 29s 584ms/step - loss: 1.4467 - val_loss: 1.4820
#
# Epoch 00002: val_loss did not improve from 1.47960
# Epoch 3/200
# 49/49 [==============================] - 29s 586ms/step - loss: 1.4297 - val_loss: 1.4783
#
# Epoch 00003: val_loss improved from 1.47960 to 1.47833, saving model to eccv_beauty_model.hdf5
# Epoch 4/200
# 49/49 [==============================] - 29s 586ms/step - loss: 1.3603 - val_loss: 1.4837
#
# Epoch 00004: val_loss did not improve from 1.47833
# Epoch 5/200
# 49/49 [==============================] - 29s 591ms/step - loss: 1.4426 - val_loss: 1.4741
#
# Epoch 00005: val_loss improved from 1.47833 to 1.47408, saving model to eccv_beauty_model.hdf5
# Epoch 6/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.3822 - val_loss: 1.5126
#
# Epoch 00006: val_loss did not improve from 1.47408
# Epoch 7/200
# 49/49 [==============================] - 29s 591ms/step - loss: 1.4416 - val_loss: 1.4848
#
# Epoch 00007: val_loss did not improve from 1.47408
# Epoch 8/200
# 49/49 [==============================] - 29s 589ms/step - loss: 1.4595 - val_loss: 1.4882
#
# Epoch 00008: val_loss did not improve from 1.47408
# Epoch 9/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.4295 - val_loss: 1.4705
#
# Epoch 00009: val_loss improved from 1.47408 to 1.47052, saving model to eccv_beauty_model.hdf5
# Epoch 10/200
# 49/49 [==============================] - 29s 590ms/step - loss: 1.4495 - val_loss: 1.4694
#
# Epoch 00010: val_loss improved from 1.47052 to 1.46942, saving model to eccv_beauty_model.hdf5
# Epoch 11/200
# 49/49 [==============================] - 29s 589ms/step - loss: 1.3926 - val_loss: 1.4949
#
# Epoch 00011: val_loss did not improve from 1.46942
# Epoch 12/200
# 49/49 [==============================] - 29s 592ms/step - loss: 1.4019 - val_loss: 1.4694
#
# Epoch 00012: val_loss improved from 1.46942 to 1.46939, saving model to eccv_beauty_model.hdf5
# Epoch 13/200
# 49/49 [==============================] - 29s 587ms/step - loss: 1.4090 - val_loss: 1.4671
#
# Epoch 00013: val_loss improved from 1.46939 to 1.46709, saving model to eccv_beauty_model.hdf5
# Epoch 14/200
# 49/49 [==============================] - 29s 592ms/step - loss: 1.4472 - val_loss: 1.4607
#
# Epoch 00014: val_loss improved from 1.46709 to 1.46069, saving model to eccv_beauty_model.hdf5
# Epoch 15/200
# 49/49 [==============================] - 29s 589ms/step - loss: 1.4884 - val_loss: 1.4798
#
# Epoch 00015: val_loss did not improve from 1.46069
# Epoch 16/200
# 49/49 [==============================] - 29s 590ms/step - loss: 1.4780 - val_loss: 1.4855
#
# Epoch 00016: val_loss did not improve from 1.46069
# Epoch 17/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.4293 - val_loss: 1.4596
#
# Epoch 00017: val_loss improved from 1.46069 to 1.45961, saving model to eccv_beauty_model.hdf5
# Epoch 18/200
# 49/49 [==============================] - 29s 590ms/step - loss: 1.4124 - val_loss: 1.4596
#
# Epoch 00018: val_loss improved from 1.45961 to 1.45959, saving model to eccv_beauty_model.hdf5
# Epoch 19/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.4012 - val_loss: 1.4755
#
# Epoch 00019: val_loss did not improve from 1.45959
# Epoch 20/200
# 49/49 [==============================] - 29s 590ms/step - loss: 1.3790 - val_loss: 1.4496
#
# Epoch 00020: val_loss improved from 1.45959 to 1.44963, saving model to eccv_beauty_model.hdf5
# Epoch 21/200
# 49/49 [==============================] - 29s 592ms/step - loss: 1.3934 - val_loss: 1.4600
#
# Epoch 00021: val_loss did not improve from 1.44963
# Epoch 22/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.3945 - val_loss: 1.4544
#
# Epoch 00022: val_loss did not improve from 1.44963
# Epoch 23/200
# 49/49 [==============================] - 29s 588ms/step - loss: 1.5087 - val_loss: 1.4558
#
# Epoch 00023: val_loss did not improve from 1.44963
# Epoch 24/200
# 49/49 [==============================] - 29s 591ms/step - loss: 1.4238 - val_loss: 1.4471
#
# Epoch 00024: val_loss improved from 1.44963 to 1.44707, saving model to eccv_beauty_model.hdf5
# Epoch 25/200
# 49/49 [==============================] - 29s 594ms/step - loss: 1.4347 - val_loss: 1.4613
#
# Epoch 00025: val_loss did not improve from 1.44707
# Epoch 26/200
# 49/49 [==============================] - 29s 591ms/step - loss: 1.3686 - val_loss: 1.4543
#
# Epoch 00026: val_loss did not improve from 1.44707
# Epoch 27/200
# 49/49 [==============================] - 29s 587ms/step - loss: 1.3688 - val_loss: 1.4453
#
# Epoch 00027: val_loss improved from 1.44707 to 1.44532, saving model to eccv_beauty_model.hdf5
# Epoch 28/200
# 49/49 [==============================] - 29s 591ms/step - loss: 1.4437 - val_loss: 1.4751
#
# Epoch 00028: val_loss did not improve from 1.44532
# Epoch 29/200
# 49/49 [==============================] - 29s 592ms/step - loss: 1.3622 - val_loss: 1.4676
#
# Epoch 00029: val_loss did not improve from 1.44532
# Epoch 30/200
# 49/49 [==============================] - 48s 984ms/step - loss: 1.4044 - val_loss: 1.4460
#
# Epoch 00030: val_loss did not improve from 1.44532
# Epoch 31/200
# 43/49 [=========================>....] - ETA: 30s - loss: 1.3514

# %%
best_iteration = np.argmin(score.history['val_loss'])+1
 
val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]
 
plt.plot(val_scores, label='val_loss')
plt.plot(train_scores, label='train_loss')
plt.legend(loc='upper right')
plt.show()

# %%
actuals = df.iloc[test_idx].score.values
predictions = beauty_model.predict(features[test_idx])
 
perf = pd.DataFrame(actuals, columns = ["actuals"])
perf["predictions"] = predictions
print("PC: ",perf[['actuals', 'predictions']].corr(method ='pearson').values[0,1])
print("MAE: ", mean_absolute_error(actuals, predictions))
print("RMSE: ", sqrt(mean_squared_error(actuals, predictions)))
perf.to_csv('./Eccv2010_prediction.csv', index=False)
# Out:
# PC:  0.12822485604104136
# MAE:  0.936480688711067
# RMSE:  1.1754594729250778
